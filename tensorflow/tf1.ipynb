# %%
import pandas as pd

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.12.0'

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=5)

model.evaluate(x_test, y_test, verbose=2)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 10s 3ms/step - loss: 0.2967 - accuracy: 0.9153
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1426 - accuracy: 0.9582
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1073 - accuracy: 0.9678
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0884 - accuracy: 0.9720
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0739 - accuracy: 0.9768
# 313/313 - 1s - loss: 0.0732 - accuracy: 0.9768 - 850ms/epoch - 3ms/step
# [0.07316374778747559, 0.9768000245094299]
